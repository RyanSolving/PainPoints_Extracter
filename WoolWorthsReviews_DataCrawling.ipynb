# %% [markdown]
# <a href="https://colab.research.google.com/github/RyanSolving/PainPoints_Extracter/blob/main/WWReviews_DataCrawling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # `Reviews database Project`

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, parse_qs, urlencode, unquote, quote
import json
import time
import random
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.engine import URL
import sqlite3
import uuid
from datetime import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Connect database google SQL

# %% [markdown]
# ### Create table stores_list

# %%
conn = sqlite3.connect('/content/drive/MyDrive/Projects/Woolies Reviews/wwreviews.db')
cursor = conn.cursor()

# %%
df = pd.read_csv('/content/drive/MyDrive/Projects/Woolies Reviews/store_list.csv')

# %%
cursor.execute('''
CREATE TABLE IF NOT EXISTS stores_list (
    Division TEXT NOT NULL,
    StoreNo INTEGER NOT NULL,
    Name TEXT,
    AddressLine1 TEXT,
    AddressLine2 TEXT,
    Suburb TEXT,
    State TEXT,
    Postcode TEXT,
    Latitude REAL,
    Longitude REAL,
    GeoLevel TEXT,
    Distance REAL,
    Phone TEXT,
    GMTZone TEXT,
    IsOpen BOOL,
    PartnerUrl REAL,
    TradingHours TEXT,
    Facilities TEXT,
    CategorisedFacilities TEXT,
    NearbyPartners REAL,
    Timestamp DATETIME,
    review_initial_url TEXT NOT NULL,
    review_nextpage_url TEXT NOT NULL,
    PRIMARY KEY (StoreNo)
)
''')

# %%
df.to_sql('stores_list',
          conn,
          if_exists='replace',
          index=False)
# Out:
# 1393

# %% [markdown]
# ### Create reviews_list

# %%
conn.execute('DROP TABLE IF EXISTS store_reviews')

conn.execute('''
CREATE TABLE store_reviews (
    ReviewID TEXT NOT NULL,
    StoreNo INTEGER NOT NULL,
    StoreName TEXT,
    UserUrl TEXT,
    UserName TEXT,
    LocalGuideBadges TEXT,
    ReviewTextSnippet TEXT,
    ReviewTextFull TEXT,  -- Add missing comma here
    Rating REAL,          -- Fixed the missing comma issue
    TimeReview TEXT,
    Timestamp DATETIME,
    PRIMARY KEY (ReviewID),
    FOREIGN KEY (StoreNo) REFERENCES stores_list(StoreNo)
)
''')
conn.commit()

# %% [markdown]
# ## Data Crawling

# %%
def extract_reviews_from_html(html_content):
    """Extract reviews from initial HTML content using BeautifulSoup."""
    soup = BeautifulSoup(html_content, 'html.parser')

    review_containers = soup.find_all('div', class_='gws-localreviews__google-review')
    all_reviews = []  # Initialize an empty list to store all reviews

    for review_container in review_containers:
        review_data = {}  # Initialize an empty dictionary for each review

        user_element = review_container.find('a', style='cursor:pointer')
        if user_element:
            review_data["UserUrl"] = user_element.get('href')
            img_element = user_element.find('img')
            review_data["UserName"] = img_element.get('alt') if img_element else ""
            review_data["LocalGuideBadges"] = ','.join([a.text for a in review_container.find_all('span', class_="QV3IV")])

        text_container = review_container.find('div', class_='Jtu6Td')
        if text_container:
            snippet_element = text_container.find('span', class_='review-snippet')
            full_text_element = text_container.find('span', class_='review-full-text')
            review_data["ReviewTextSnippet"] = snippet_element.text if snippet_element else ""

            if full_text_element:
              review_data["ReviewTextFull"] = full_text_element.text
            else:
              review_data["ReviewTextFull"] = text_container.text
        ratings = review_container.find('span',class_="z3HNkc")
        if ratings:
            review_data["Rating"] = str(ratings.get('aria-label')).replace("Rated ", "").replace(" out of 5,", "")

        time = review_container.find('span', class_="dehysf")
        if time:
          review_data["TimeReview"] = time.text

        all_reviews.append(review_data) # Append the dictionary to the list

    return pd.DataFrame(all_reviews) # Return the final dataframe made from all reviews

# %%
def get_next_page_token(html_content):
  """Get the next page token from the HTML content"""
  soup = BeautifulSoup(html_content, 'html.parser')
  reviews_block = soup.find('div',class_='gws-localreviews__general-reviews-block')
  if reviews_block:
    return reviews_block.get('data-next-page-token')
  return None

# %%
def construct_async_url_orginal(base_url, initial_url, next_page_token):
     """Construct an async URL using parameters from original url.

      Args:
        base_url: The base url from google api
        initial_url: Initial url that contained the review data.
        next_page_token: The next page token for the next page

      Returns:
         url to load more reviews.
     """
     parsed_url = urlparse(initial_url)
     query_params = parse_qs(parsed_url.query)

     async_param_string = query_params.get('async', [''])[0]
     if not async_param_string:
        return None

    # Split at the first colon
     async_params = dict(item.split(':', 1) for item in async_param_string.split(','))

     if next_page_token:
        async_params['next_page_token'] = next_page_token

     full_params = urlencode(async_params) # Remove quote_via=urlencode
     full_params = unquote(full_params)

     return f"{base_url}?{full_params}"

# %%
def construct_async_url(next_page_url, next_page_token):
  """Construct url from example of next_page_url and next_page_token
  Args:
    next_page_url: string, next page url from google
    next_page_token: string, next page token from google

  Returns:
    url to load more reviews.
  """
  #Split into based_url and update_url
  split_url = next_page_url.split(',')
  based_url = split_url[0]
  update_token_url = split_url[1:]
  dict_params = dict(item.split(':') for item in update_token_url)
  dict_params['next_page_token'] = quote(next_page_token)
  dict_params = [f'{key}:{value}' for key,value in dict_params.items()]
  dict_params = ','.join(dict_params)
  return f"{based_url},{dict_params}"

# %%
def load_more_reviews(async_url):
  """Load more reviews from the given async URL.
  Args:
    async_url: string, async url to load more reviews.

  Returns:
    HTML content
  """
  headers = {"User-Agent": "Mozilla/5.0"}
  response = requests.get(async_url, headers=headers)

  if response.status_code == 200:
    return response.text
  else:
    print(f"Failed to load more reviews. Status code: {response.status_code}")
    return None

# %%
# extract_reviews_from_html, get_next_page_token, construct_async_url, load_more_reviews

def crawl_reviews_async(html_content, next_page_url):
    current_html = html_content
    total_reviews = pd.DataFrame(columns=['StoreName','UserUrl', 'UserName', 'LocalGuideBadges', 'ReviewTextSnippet', 'ReviewTextFull', 'Rating', 'TimeReview'])

    while True:  # This is a loop that keeps going until there's no next page
        reviews = extract_reviews_from_html(current_html)

        # Append reviews to the DataFrame
        total_reviews = pd.concat([total_reviews, reviews], ignore_index=True)

        # Get next page token
        next_page_token = get_next_page_token(current_html)

        # If there's no next page token, exit the loop
        if not next_page_token:
            break

        # Construct async URL for the next page
        async_url = construct_async_url(next_page_url, next_page_token)

        # Load the next page content
        if async_url:
            new_html = load_more_reviews(async_url)
            if new_html:
                current_html = new_html
            else:
                break
        else:
            break

        # Sleep between requests to avoid overwhelming the server
        time.sleep(random.uniform(4, 6))

    return total_reviews

# %% [markdown]
# ## Prepare for crawling

# %%
query_2 = """
SELECT COUNT(DISTINCT StoreNo)
FROM stores_list
WHERE State = 'VIC' AND Division = 'SUPERMARKETS'
"""
cursor.execute(query_2).fetchall()
# Out:
# [(272,)]

# %%
query = 'SELECT StoreNo, review_initial_url, review_nextpage_url FROM stores_list WHERE State="VIC" and Division="SUPERMARKETS"'
cursor = conn.execute(query)
review_links = cursor.fetchall()

# %%
review_links[0]
# Out:
# (3304,
#  'https://www.google.com/async/reviewDialog?vet=10ahUKEwj37eCRmfmKAxUrSWwGHRomMCsQlIwOCKcG..i&ei=KW-IZ7e1M6uSseMPmszA2QI&opi=89978449&rlz=1C1FKPE_en-GBAU1093AU1093&yv=3&cs=0&async=feature_id:0x6ad642ca44bc9591%3A0x18895914c0fe118b,review_source:All%20reviews,sort_by:qualityScore,is_owner:false,filter_text:,associated_topic:,next_page_token:,async_id_prefix:,_pms:s,_fmt:pc,_basejs:%2Fxjs%2F_%2Fjs%2Fk%3Dxjs.s.en_GB.imokO5pDFSw.2018.O%2Fam%3DAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAACAABQEIAAAAAABQAAgAAAAAAAAAABIAAAAAAEACASBASAAAgAAAAAAAsAAAAAgsAIEBAAAAAAAAAAIAAACAQARgv_84AAAAAAAAAAAAIABEAAAAAADgAgAgCGo3QAAAAACAAAAAAAgAAAAEAAQAAAAUAAAAQAAAAAAIAAAAAAAAAAgAAAAAAQD6QwAAAAAAAAAAAAAAAgAAAAAAaIACAAL4AQAAAAAAgAMAAACAAAEAAMfAAAQAAAAAAADgHgAeDwiHFBYAAAAAAAAAAAAAAAAQgATBHEh_QQACAAAAAAAAAAAAAAAAAABIETRxuQFAAQ%2Fdg%3D0%2Fbr%3D1%2Frs%3DACT90oEmcrTwDGRBHFigA4Hte2jSNiyLXQ,_basecss:%2Fxjs%2F_%2Fss%2Fk%3Dxjs.s.7eaQE2ygUs0.L.B1.O%2Fam%%2Fbr%3D1%2Frs%3DACT90oEvTh5q2A_EcnKoNyL6Aru3GqFmuw,_basecomb:%2Fxjs%2F_%2Fjs%2Fk%3Dxjs.s.en_GB.imokO5pDFSw.2018.O%2Fck%3Dxjs.s.7eaQE2ygUs0.L.B1.O%2Fam%3DAJA6BAgBAAAgAACAEAAqAAgAAAAAAAAAAAAAAAAAAAAAAAAAACABAAAAAgAAAAAAABAAACAQBQGImQAAAIJTAAiwAwAAAAD4ABJxKgABAEACASBASAAAgAAAAYAAsAECAAgsAIEBIAgAACAAgAMAAASAQARgv_85MACAAQAAgAAAISBEAAEYAkDjAiAhKH8_QOIHAAWEAEAAAAgAAKAEPATDAAQVAAM8QAgAAAAIAAAAAAAAEAggBAAAA1D6QwQQAKAHgADwAQBIgggAMAQAaIBCABL4AQAEAAAAgCMAAgGAAGEKAMfAAAQAAAAAAADgHgAeDwiHFBYAAAAAAAAAAAAAAAAQgATBHEh_QQACAAAAAAAAAAAAAAAAAABIETRxuQFAAQ%2Fd%3D1%2Fed%3D1%2Fdg%3D0%2Fbr%3D1%2Fujg%3D1%2Frs%3DACT90oGVE-wJGFrfOI-mdQtlS-9ka9tfqQ',
#  'https://www.google.com/async/reviewSort?vet=12ahUKEwjk0-aVmfmKAxXgSWwGHeNUEfEQxyx6BAgBED0..i&ved=2ahUKEwjk0-aVmfmKAxXgSWwGHeNUEfEQjit6BQgBEIME&bl=2lWB&s=web&opi=89978449&rlz=1C1FKPE_en-GBAU1093AU1093&yv=3&cs=0&async=feature_id:0x6ad642ca44bc9591%3A0x18895914c0fe118b,review_source:All%20reviews,sort_by:qualityScore,is_owner:false,filter_text:,associated_topic:,next_page_token:CAESY0NBRVFDaHBFUTJwRlNVRlNTWEJEWjI5QlVEZGZURUpGVkZoZlgxOWZSV2hEVmxCeWRqbERaRTFPVVdOSVJ6SlZSVUZCUVVGQlIyZHVPVEphV1VOaVdWWnplbWhSV1VGRFNVRQ%3D%3D,_pms:s,_fmt:pc,_basejs:%2Fxjs%2F_%2Fjs%2Fk%3Dxjs.s.en_GB.imokO5pDFSw.2018.O%2Fam%3DAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAACAABQEIAAAAAABQAAgAAAAAAAAAABIAAAAAAEACASBASAAAgAAAAAAAsAAAAAgsAIEBAAAAAAAAAAIAAACAQARgv_84AAAAAAAAAAAAIABEAAAAAADgAgAgCGo3QAAAAACAAAAAAAgAAAAEAAQAAAAUAAAAQAAAAAAIAAAAAAAAAAgAAAAAAQD6QwAAAAAAAAAAAAAAAgAAAAAAaIACAAL4AQAAAAAAgAMAAACAAAEAAMfAAAQAAAAAAADgHgAeDwiHFBYAAAAAAAAAAAAAAAAQgATBHEh_QQACAAAAAAAAAAAAAAAAAABIETRxuQFAAQ%2Fdg%3D0%2Fbr%3D1%2Frs%3DACT90oEmcrTwDGRBHFigA4Hte2jSNiyLXQ,_basecss:%2Fxjs%2F_%2Fss%2Fk%3Dxjs.s.7eaQE2ygUs0.L.B1.O%2Fam%%2Fbr%3D1%2Frs%3DACT90oEvTh5q2A_EcnKoNyL6Aru3GqFmuw,_basecomb:%2Fxjs%2F_%2Fjs%2Fk%3Dxjs.s.en_GB.imokO5pDFSw.2018.O%2Fck%3Dxjs.s.7eaQE2ygUs0.L.B1.O%2Fam%3DAJA6BAgBAAAgAACAEAAqAAgAAAAAAAAAAAAAAAAAAAAAAAAAACABAAAAAgAAAAAAABAAACAQBQGImQAAAIJTAAiwAwAAAAD4ABJxKgABAEACASBASAAAgAAAAYAAsAECAAgsAIEBIAgAACAAgAMAAASAQARgv_85MACAAQAAgAAAISBEAAEYAkDjAiAhKH8_QOIHAAWEAEAAAAgAAKAEPATDAAQVAAM8QAgAAAAIAAAAAAAAEAggBAAAA1D6QwQQAKAHgADwAQBIgggAMAQAaIBCABL4AQAEAAAAgCMAAgGAAGEKAMfAAAQAAAAAAADgHgAeDwiHFBYAAAAAAAAAAAAAAAAQgATBHEh_QQACAAAAAAAAAAAAAAAAAABIETRxuQFAAQ%2Fd%3D1%2Fed%3D1%2Fdg%3D0%2Fbr%3D1%2Fujg%3D1%2Frs%3DACT90oGVE-wJGFrfOI-mdQtlS-9ka9tfqQ')

# %%
#Extract list of successful added reviews stores
distinct_storeno = conn.execute('''
select distinct StoreNo
from reviews_list
''').fetchall()
distinct_storeno = [item[0] for item in distinct_storeno]

# %%
conn.execute('''SELECT
	count(distinct StoreNo)
FROM reviews_list ''').fetchall()
# Out:
# [(272,)]

# %%
distinct_storeno
# Out:
# [3304,
#  3450,
#  3438,
#  3028,
#  3452,
#  3711,
#  8281,
#  3089,
#  3163,
#  3813,
#  3762,
#  3453,
#  8285,
#  3332,
#  3306,
#  3311,
#  3779,
#  3398,
#  8382,
#  3968,
#  3195,
#  3427,
#  3579,
#  3607,
#  3389,
#  3362,
#  3325,
#  3169,
#  3188,
#  8827,
#  3178,
#  3094,
#  3403,
#  3999,
#  3139,
#  3411,
#  3576,
#  3135,
#  3307,
#  3431,
#  3138,
#  3115,
#  3855,
#  3267,
#  3391,
#  3384,
#  3079,
#  3964,
#  3162,
#  3197,
#  3221,
#  8824,
#  3121,
#  3096,
#  3292,
#  8972,
#  8823,
#  3145,
#  3127,
#  3353,
#  3153,
#  3672,
#  3117,
#  3298,
#  8785,
#  3157,
#  3136,
#  3186,
#  3291,
#  3205,
#  3118,
#  3155,
#  3202,
#  3110,
#  8826,
#  3317,
#  3368,
#  3340,
#  3174,
#  3060,
#  3209,
#  3140,
#  3329,
#  3122,
#  3295,
#  3327,
#  3235,
#  3181,
#  3179,
#  3128,
#  3150,
#  3454,
#  3147,
#  3171,
#  3336,
#  3763,
#  3301,
#  3283,
#  3802,
#  3969,
#  3173,
#  3289,
#  3806,
#  3227,
#  3055,
#  3062,
#  3182,
#  3187,
#  3183,
#  3129,
#  3392,
#  3355,
#  3850,
#  3399,
#  3903,
#  3809,
#  3146,
#  3192,
#  3960,
#  3149,
#  3159,
#  3130,
#  3109,
#  3204,
#  3285,
#  3063,
#  3670,
#  3189,
#  3282,
#  3061,
#  3343,
#  3223,
#  3141,
#  3091,
#  3354,
#  3151,
#  3371,
#  3216,
#  3805,
#  3281,
#  3382,
#  3108,
#  3337,
#  3112,
#  3349,
#  3124,
#  3143,
#  3742,
#  3369,
#  3376,
#  3165,
#  3168,
#  3345,
#  3104,
#  3996,
#  3807,
#  3105,
#  3191]

# %%
logs = pd.read_csv('/content/drive/MyDrive/Projects/Woolies Reviews/crawling_logs.csv')

# %%
for store_id, initial_url, next_page_url in review_links:
  if str(store_id) in [str(x) for x in distinct_storeno]: #check if store already exist, convert store_id to string to ensure proper type comparison
    print(f'Skipping {store_id} since it has been processed previously')
    logs = pd.concat([logs, pd.DataFrame([{'store': store_id, 'status': 'skipped'}])], ignore_index=True)
    continue
  try:
    headers = {"User-Agent": "Mozilla/5.0"}
    params = {
    "gl": "US",  # Geolocation: United States
    "hl": "en"   # Language: English
    }
    respond = requests.get(initial_url, headers=headers, params = params)
    respond.raise_for_status() # raise an exception for 4xx and 5xx errors
    initial_html = respond.content
    output = crawl_reviews_async(initial_html, next_page_url)

    if output.empty:
      logs = logs.append({'store': store_id, 'status': 'no_reviews'}, ignore_index=True)
      continue

    output['StoreNo'] = store_id
    output['StoreName'] = BeautifulSoup(initial_html, 'html.parser').find('div',class_='Lhccdd').find('div').text
    output['ReviewID'] = [str(uuid.uuid4()) for _ in range(len(output))]
    output['Timestamp'] = pd.to_datetime(datetime.now())

    # Convert Rating into integer
    output['Rating'] = output['Rating'].str[0].astype(int)

    #Reoder columns
    new_order = ['ReviewID','StoreNo','StoreName','UserUrl','UserName','LocalGuideBadges','ReviewTextSnippet','ReviewTextFull','Rating','TimeReview','Timestamp']
    output = output[new_order]

    #inserting the df to SQL
    output.to_sql('reviews_list',
                conn,
                if_exists='append',
                index=False)
    conn.commit()

    time.sleep(random.uniform(2, 3))
    # Correct way to append a new row to logs
    logs = pd.concat([logs, pd.DataFrame([{'store': store_id, 'status': 'success'}])], ignore_index=True)
    print(f'Success added reviews of store_id {store_id} at {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}')

  except Exception as e:
    #append failure to logs
    logs = pd.concat([logs, pd.DataFrame([{'store': store_id, 'status': 'fail'}])], ignore_index=True)
    print(f"Error processing store {store_id}: {e}")

conn.commit() # Save the changes
conn.close()
logs.to_csv('/content/drive/MyDrive/Projects/Woolies Reviews/crawling_logs.csv', index=False)

print(logs)
print("Reviews processed and added to the database")
# Out:
# Skipping 3304 since it has been processed previously
# Skipping 3450 since it has been processed previously
# Skipping 3438 since it has been processed previously
# Skipping 3028 since it has been processed previously
# Skipping 3452 since it has been processed previously
# Skipping 3711 since it has been processed previously
# Skipping 8281 since it has been processed previously
# Skipping 3089 since it has been processed previously
# Skipping 3163 since it has been processed previously
# Skipping 3813 since it has been processed previously
# Skipping 3762 since it has been processed previously
# Skipping 3453 since it has been processed previously
# Skipping 8285 since it has been processed previously
# Skipping 3332 since it has been processed previously
# Skipping 3306 since it has been processed previously
# Skipping 3311 since it has been processed previously
# Skipping 3779 since it has been processed previously
# Skipping 3398 since it has been processed previously
# Skipping 8382 since it has been processed previously
# Skipping 3968 since it has been processed previously
# Skipping 3195 since it has been processed previously
# Skipping 3427 since it has been processed previously
# Skipping 3579 since it has been processed previously
# Skipping 3607 since it has been processed previously
# Skipping 3389 since it has been processed previously
# Skipping 3362 since it has been processed previously
# Skipping 3325 since it has been processed previously
# Skipping 3169 since it has been processed previously
# Skipping 3188 since it has been processed previously
# Skipping 8827 since it has been processed previously
# Skipping 3178 since it has been processed previously
# Skipping 3094 since it has been processed previously
# Skipping 3403 since it has been processed previously
# Skipping 3999 since it has been processed previously
# Skipping 3139 since it has been processed previously
# Skipping 3411 since it has been processed previously
# Skipping 3576 since it has been processed previously
# Skipping 3135 since it has been processed previously
# Skipping 3307 since it has been processed previously
# Skipping 3431 since it has been processed previously
# Skipping 3138 since it has been processed previously
# Skipping 3115 since it has been processed previously
# Skipping 3855 since it has been processed previously
# Skipping 3267 since it has been processed previously
# Skipping 3391 since it has been processed previously
# Skipping 3384 since it has been processed previously
# Skipping 3079 since it has been processed previously
# Skipping 3964 since it has been processed previously
# Skipping 3162 since it has been processed previously
# Skipping 3197 since it has been processed previously
# Skipping 3221 since it has been processed previously
# Skipping 8824 since it has been processed previously
# Skipping 3121 since it has been processed previously
# Skipping 3096 since it has been processed previously
# Skipping 3292 since it has been processed previously
# Skipping 8972 since it has been processed previously
# Skipping 8823 since it has been processed previously
# Skipping 3145 since it has been processed previously
# Skipping 3127 since it has been processed previously
# Skipping 3353 since it has been processed previously
# Skipping 3153 since it has been processed previously
# Skipping 3672 since it has been processed previously
# Skipping 3117 since it has been processed previously
# Skipping 3298 since it has been processed previously
# Skipping 8785 since it has been processed previously
# Skipping 3157 since it has been processed previously
# Skipping 3136 since it has been processed previously
# Skipping 3186 since it has been processed previously
# Skipping 3291 since it has been processed previously
# Skipping 3205 since it has been processed previously
# Skipping 3118 since it has been processed previously
# Skipping 3155 since it has been processed previously
# Skipping 3202 since it has been processed previously
# Skipping 3110 since it has been processed previously
# Skipping 8826 since it has been processed previously
# Skipping 3317 since it has been processed previously
# Skipping 3368 since it has been processed previously
# Success added reviews of store_id 3185 at 2025-01-21 10:36:13
# Success added reviews of store_id 3161 at 2025-01-21 10:37:16
# Skipping 3340 since it has been processed previously
# Skipping 3174 since it has been processed previously
# Skipping 3060 since it has been processed previously
# Skipping 3209 since it has been processed previously
# Skipping 3140 since it has been processed previously
# Skipping 3329 since it has been processed previously
# Skipping 3122 since it has been processed previously
# Skipping 3295 since it has been processed previously
# Skipping 3327 since it has been processed previously
# Skipping 3235 since it has been processed previously
# Skipping 3181 since it has been processed previously
# Skipping 3179 since it has been processed previously
# Skipping 3128 since it has been processed previously
# Skipping 3150 since it has been processed previously
# Skipping 3454 since it has been processed previously
# Skipping 3147 since it has been processed previously
# Skipping 3171 since it has been processed previously
# Skipping 3336 since it has been processed previously
# Skipping 3763 since it has been processed previously
# Skipping 3301 since it has been processed previously
# Skipping 3283 since it has been processed previously
# Skipping 3802 since it has been processed previously
# Skipping 3969 since it has been processed previously
# Skipping 3173 since it has been processed previously
# Skipping 3289 since it has been processed previously
# Skipping 3806 since it has been processed previously
# Skipping 3227 since it has been processed previously
# Skipping 3055 since it has been processed previously
# Skipping 3062 since it has been processed previously
# Skipping 3182 since it has been processed previously
# Skipping 3187 since it has been processed previously
# Skipping 3183 since it has been processed previously
# Skipping 3129 since it has been processed previously
# Skipping 3392 since it has been processed previously
# Skipping 3355 since it has been processed previously
# Skipping 3850 since it has been processed previously
# Skipping 3399 since it has been processed previously
# Skipping 3903 since it has been processed previously
# Skipping 3809 since it has been processed previously
# Skipping 3146 since it has been processed previously
# Skipping 3192 since it has been processed previously
# Skipping 3960 since it has been processed previously
# Skipping 3149 since it has been processed previously
# Skipping 3159 since it has been processed previously
# Skipping 3130 since it has been processed previously
# Skipping 3109 since it has been processed previously
# Skipping 3204 since it has been processed previously
# Skipping 3285 since it has been processed previously
# Skipping 3063 since it has been processed previously
# Skipping 3670 since it has been processed previously
# Skipping 3189 since it has been processed previously
# Skipping 3282 since it has been processed previously
# Skipping 3061 since it has been processed previously
# Skipping 3343 since it has been processed previously
# Skipping 3223 since it has been processed previously
# Skipping 3141 since it has been processed previously
# Skipping 3091 since it has been processed previously
# Skipping 3354 since it has been processed previously
# Skipping 3151 since it has been processed previously
# Skipping 3371 since it has been processed previously
# Skipping 3216 since it has been processed previously
# Skipping 3805 since it has been processed previously
# Skipping 3281 since it has been processed previously
# Skipping 3382 since it has been processed previously
# Skipping 3108 since it has been processed previously
# Skipping 3337 since it has been processed previously
# Skipping 3112 since it has been processed previously
# Skipping 3349 since it has been processed previously
# Skipping 3124 since it has been processed previously
# Skipping 3143 since it has been processed previously
# Skipping 3742 since it has been processed previously
# Skipping 3369 since it has been processed previously
# Skipping 3376 since it has been processed previously
# Skipping 3165 since it has been processed previously
# Skipping 3168 since it has been processed previously
# Skipping 3345 since it has been processed previously
# Skipping 3104 since it has been processed previously
# Skipping 3996 since it has been processed previously
# Skipping 3807 since it has been processed previously
# Skipping 3105 since it has been processed previously
# Skipping 3191 since it has been processed previously
# Success added reviews of store_id 3125 at 2025-01-21 10:40:17
# Success added reviews of store_id 3804 at 2025-01-21 10:43:23
# Success added reviews of store_id 3176 at 2025-01-21 10:46:31
# Success added reviews of store_id 3123 at 2025-01-21 10:49:37
# Success added reviews of store_id 3113 at 2025-01-21 10:52:41
# Success added reviews of store_id 3100 at 2025-01-21 10:55:48
# Success added reviews of store_id 3302 at 2025-01-21 10:58:39
# Success added reviews of store_id 3339 at 2025-01-21 11:01:28
# Success added reviews of store_id 3007 at 2025-01-21 11:04:42
# Success added reviews of store_id 3324 at 2025-01-21 11:07:47
# Success added reviews of store_id 3259 at 2025-01-21 11:10:34
# Success added reviews of store_id 3144 at 2025-01-21 11:13:35
# Success added reviews of store_id 3803 at 2025-01-21 11:16:43
# Success added reviews of store_id 3167 at 2025-01-21 11:19:49
# Success added reviews of store_id 3940 at 2025-01-21 11:22:56
# Success added reviews of store_id 3244 at 2025-01-21 11:25:54
# Success added reviews of store_id 3320 at 2025-01-21 11:28:54
# Success added reviews of store_id 3134 at 2025-01-21 11:31:20
# Success added reviews of store_id 3390 at 2025-01-21 11:34:29
# Success added reviews of store_id 3034 at 2025-01-21 11:37:19
# Success added reviews of store_id 3092 at 2025-01-21 11:40:09
# Success added reviews of store_id 3240 at 2025-01-21 11:43:16
# Success added reviews of store_id 3172 at 2025-01-21 11:46:28
# Success added reviews of store_id 3004 at 2025-01-21 11:49:28
# Success added reviews of store_id 3184 at 2025-01-21 11:52:40
# Success added reviews of store_id 3901 at 2025-01-21 11:55:42
# Success added reviews of store_id 3318 at 2025-01-21 11:57:11
# Success added reviews of store_id 3273 at 2025-01-21 12:00:18
# Success added reviews of store_id 3142 at 2025-01-21 12:03:11
# Success added reviews of store_id 3241 at 2025-01-21 12:05:57
# Success added reviews of store_id 3400 at 2025-01-21 12:08:50
# Success added reviews of store_id 3316 at 2025-01-21 12:11:32
# Success added reviews of store_id 3102 at 2025-01-21 12:14:28
# Success added reviews of store_id 3075 at 2025-01-21 12:17:06
# Success added reviews of store_id 3116 at 2025-01-21 12:20:02
# Success added reviews of store_id 3395 at 2025-01-21 12:23:09
# Success added reviews of store_id 3193 at 2025-01-21 12:26:15
# Success added reviews of store_id 3716 at 2025-01-21 12:28:10
# Success added reviews of store_id 3310 at 2025-01-21 12:31:13
# Success added reviews of store_id 3308 at 2025-01-21 12:34:14
# Success added reviews of store_id 3341 at 2025-01-21 12:37:21
# Success added reviews of store_id 3714 at 2025-01-21 12:38:54
# Success added reviews of store_id 3357 at 2025-01-21 12:39:38
# Success added reviews of store_id 3604 at 2025-01-21 12:42:31
# Success added reviews of store_id 3058 at 2025-01-21 12:45:24
# Success added reviews of store_id 3211 at 2025-01-21 12:48:22
# Success added reviews of store_id 3275 at 2025-01-21 12:51:24
# Success added reviews of store_id 3364 at 2025-01-21 12:54:10
# Success added reviews of store_id 3218 at 2025-01-21 12:57:15
# Success added reviews of store_id 3120 at 2025-01-21 13:00:16
# Success added reviews of store_id 3166 at 2025-01-21 13:03:19
# Success added reviews of store_id 3900 at 2025-01-21 13:05:17
# Success added reviews of store_id 3565 at 2025-01-21 13:08:00
# Success added reviews of store_id 3286 at 2025-01-21 13:11:01
# Success added reviews of store_id 3119 at 2025-01-21 13:11:46
# Success added reviews of store_id 3002 at 2025-01-21 13:14:48
# Success added reviews of store_id 3222 at 2025-01-21 13:17:57
# Success added reviews of store_id 3567 at 2025-01-21 13:20:43
# Success added reviews of store_id 3303 at 2025-01-21 13:23:48
# Success added reviews of store_id 3074 at 2025-01-21 13:27:00
# Success added reviews of store_id 3272 at 2025-01-21 13:29:58
# Success added reviews of store_id 3287 at 2025-01-21 13:33:04
# Success added reviews of store_id 3280 at 2025-01-21 13:36:11
# Success added reviews of store_id 3266 at 2025-01-21 13:39:16
# Success added reviews of store_id 3278 at 2025-01-21 13:42:25
# Success added reviews of store_id 3309 at 2025-01-21 13:45:25
# Success added reviews of store_id 3603 at 2025-01-21 13:48:20
# Success added reviews of store_id 3923 at 2025-01-21 13:51:20
# Success added reviews of store_id 3066 at 2025-01-21 13:54:24
# Success added reviews of store_id 3261 at 2025-01-21 13:57:28
# Success added reviews of store_id 3290 at 2025-01-21 14:00:26
# Success added reviews of store_id 3366 at 2025-01-21 14:03:23
# Success added reviews of store_id 3393 at 2025-01-21 14:06:26
# Success added reviews of store_id 3160 at 2025-01-21 14:09:34
# Success added reviews of store_id 3148 at 2025-01-21 14:12:47
# Success added reviews of store_id 3214 at 2025-01-21 14:15:39
# Success added reviews of store_id 3299 at 2025-01-21 14:18:39
# Success added reviews of store_id 3208 at 2025-01-21 14:21:37
# Success added reviews of store_id 3271 at 2025-01-21 14:24:35
# Success added reviews of store_id 3315 at 2025-01-21 14:27:25
# Success added reviews of store_id 3247 at 2025-01-21 14:30:37
# Success added reviews of store_id 3137 at 2025-01-21 14:33:39
# Success added reviews of store_id 3250 at 2025-01-21 14:36:23
# Success added reviews of store_id 3203 at 2025-01-21 14:39:32
# Success added reviews of store_id 3319 at 2025-01-21 14:42:03
# Success added reviews of store_id 3381 at 2025-01-21 14:44:51
# Success added reviews of store_id 3101 at 2025-01-21 14:47:45
# Success added reviews of store_id 3344 at 2025-01-21 14:50:32
# Success added reviews of store_id 3177 at 2025-01-21 14:53:04
# Success added reviews of store_id 3213 at 2025-01-21 14:55:57
# Success added reviews of store_id 3361 at 2025-01-21 14:57:58
# Success added reviews of store_id 3219 at 2025-01-21 15:01:01
# Success added reviews of store_id 3164 at 2025-01-21 15:04:02
# Success added reviews of store_id 3263 at 2025-01-21 15:07:13
# Success added reviews of store_id 3106 at 2025-01-21 15:10:07
# Success added reviews of store_id 3088 at 2025-01-21 15:13:12
# Success added reviews of store_id 3196 at 2025-01-21 15:16:19
# Success added reviews of store_id 3321 at 2025-01-21 15:19:29
# Success added reviews of store_id 3229 at 2025-01-21 15:22:29
# Success added reviews of store_id 3352 at 2025-01-21 15:25:38
# Success added reviews of store_id 3072 at 2025-01-21 15:28:38
# Success added reviews of store_id 3114 at 2025-01-21 15:31:43
# Success added reviews of store_id 3330 at 2025-01-21 15:34:42
# Success added reviews of store_id 3053 at 2025-01-21 15:37:50
# Success added reviews of store_id 3293 at 2025-01-21 15:40:56
# Success added reviews of store_id 3248 at 2025-01-21 15:43:30
# Success added reviews of store_id 3126 at 2025-01-21 15:46:26
# Success added reviews of store_id 3268 at 2025-01-21 15:49:18
# Success added reviews of store_id 3260 at 2025-01-21 15:52:18
# Success added reviews of store_id 3201 at 2025-01-21 15:55:21
# Success added reviews of store_id 5673 at 2025-01-21 15:58:22
# Success added reviews of store_id 5674 at 2025-01-21 16:01:25
#      store   status
# 0     3304  success
# 1     3450  success
# 2     3438  success
# 3     3028  success
# 4     3452  success
# ..     ...      ...
# 504   3268  success
# 505   3260  success
# 506   3201  success
# 507   5673  success
# 508   5674  success
#
# [509 rows x 2 columns]
# Reviews processed and added to the database

# %%
conn.commit() # Save the changes
conn.close()
logs.to_csv('/content/drive/MyDrive/Projects/Woolies Reviews/crawling_logs.csv', index=False)

# %%
(initial_url, next_page_url)=conn.execute('''
Select review_initial_url, review_nextpage_url
From stores_list
Where StoreNo = 3855
''').fetchall()[0]

# %%
df.query('StoreNo == c and Division=="SUPERMARKETS"')[['review_initial_url','review_nextpage_url']].values
# Out:
# array([['https://www.google.com/async/reviewDialog?vet=10ahUKEwjYnOvvxvmKAxUhd2wGHTDWBFYQlIwOCPgF..i&ei=Hp-IZ9iVLaHuseMPsKyTsAU&opi=89978449&rlz=1C1FKPE_en-GBAU1093AU1093&sca_esv=bcbd4b002db38cd9&yv=3&cs=0&async=feature_id:0x6ad438e8d754b489%3A0xf4867df92ae95f43,review_source:All%20reviews,sort_by:qualityScore,is_owner:false,filter_text:,associated_topic:,next_page_token:,async_id_prefix:,_pms:s,_fmt:pc,_basejs:%2Fxjs%2F_%2Fjs%2Fk%3Dxjs.s.en_GB.ZIq5YyAIbUU.2018.O%2Fam%3DAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAACAABQEIAAAAAABQAAgAAAAAAAAAABIAAAAAAEACASBASAAAgAAAAAAAsAAAAAgsAIEBAAAAAAAAAAIAAACAQARgv_84AAAAAAAAAAAAIABEAAAAAADgAgAgCGo3QAAAAACAAAAAAAgAAAAEAAQAAAAUAAAAQAAAAAAIAAAAAAAAAAgAAAAAAQD6QwAAAAAAAAAAAAAAAgAAAAAAaIACAAL4AQAAAAAAgAMAAACAAAEAAMfAAAQAAAAAAADgHgAeDwiHFBYAAAAAAAAAAAAAAAAQgATBHEh_QQACAAAAAAAAAAAAAAAAAABIETRxuQFAAQ%2Fdg%3D0%2Fbr%3D1%2Frs%3DACT90oGlBOIjHcpfgjtPy3FmV8jc-lwiMw,_basecss:%2Fxjs%2F_%2Fss%2Fk%3Dxjs.s.9Bth82x0PFM.L.B1.O%2Fam%%2Fbr%3D1%2Frs%3DACT90oHR5eqlMam3ZEvkn3UMTIwyNMFJuA,_basecomb:%2Fxjs%2F_%2Fjs%2Fk%3Dxjs.s.en_GB.ZIq5YyAIbUU.2018.O%2Fck%3Dxjs.s.9Bth82x0PFM.L.B1.O%2Fam%3DAJA6BAgBAAAgAACAEAAqAAgAAAAAAAAAAAAAAAAAAAAAAAAAACABAAAAAgAAAAAAABAAACAQBQGImQAAAIJTAAiwAwAAAAD4ABJxKgABAEACASBASAAAgAAAAYAAsAECAAgsAIEBIAgAACAAgAMAAASAQARgv_85MACAAQAAgAAAISBEAAEYAkDjAiAhKH8_QOIHAAWEAEAAAAgAAKAEPATDAAQVAAM8QAgAAAAIAAAAAAAAEAggBAAAA1D6QwQQAKAHgADwAQBIgggAMAQAaIBCABL4AQAEAAAAgCMAAgGAAGEKAMfAAAQAAAAAAADgHgAeDwiHFBYAAAAAAAAAAAAAAAAQgATBHEh_QQACAAAAAAAAAAAAAAAAAABIETRxuQFAAQ%2Fd%3D1%2Fed%3D1%2Fdg%3D0%2Fbr%3D1%2Fujg%3D1%2Frs%3DACT90oFyvZ7kgaKtsTqOSldpVVmZhH1NwA',
#         'https://www.google.com/async/reviewSort?vet=12ahUKEwiA063xxvmKAxUFT2wGHZGYI5oQxyx6BAgBED0..i&ved=2ahUKEwiA063xxvmKAxUFT2wGHZGYI5oQjit6BQgBEIUD&bl=2lWB&s=web&opi=89978449&rlz=1C1FKPE_en-GBAU1093AU1093&sca_esv=bcbd4b002db38cd9&yv=3&cs=0&async=feature_id:0x6ad438e8d754b489%3A0xf4867df92ae95f43,review_source:All%20reviews,sort_by:qualityScore,is_owner:false,filter_text:,associated_topic:,next_page_token:CAESY0NBRVFDaHBFUTJwRlNVRlNTWEJEWjI5QlVEZGZURXRUTm5WZlgxOWZSV2hEZEdsRFFVbHRRV2h0VGtsUVYzQkVORUZCUVVGQlIyZHVPVE42WjBOamNVWldMVzlCV1VGRFNVRQ%3D%3D,_pms:s,_fmt:pc,_basejs:%2Fxjs%2F_%2Fjs%2Fk%3Dxjs.s.en_GB.ZIq5YyAIbUU.2018.O%2Fam%3DAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAACAABQEIAAAAAABQAAgAAAAAAAAAABIAAAAAAEACASBASAAAgAAAAAAAsAAAAAgsAIEBAAAAAAAAAAIAAACAQARgv_84AAAAAAAAAAAAIABEAAAAAADgAgAgCGo3QAAAAACAAAAAAAgAAAAEAAQAAAAUAAAAQAAAAAAIAAAAAAAAAAgAAAAAAQD6QwAAAAAAAAAAAAAAAgAAAAAAaIACAAL4AQAAAAAAgAMAAACAAAEAAMfAAAQAAAAAAADgHgAeDwiHFBYAAAAAAAAAAAAAAAAQgATBHEh_QQACAAAAAAAAAAAAAAAAAABIETRxuQFAAQ%2Fdg%3D0%2Fbr%3D1%2Frs%3DACT90oGlBOIjHcpfgjtPy3FmV8jc-lwiMw,_basecss:%2Fxjs%2F_%2Fss%2Fk%3Dxjs.s.9Bth82x0PFM.L.B1.O%2Fam%%2Fbr%3D1%2Frs%3DACT90oHR5eqlMam3ZEvkn3UMTIwyNMFJuA,_basecomb:%2Fxjs%2F_%2Fjs%2Fk%3Dxjs.s.en_GB.ZIq5YyAIbUU.2018.O%2Fck%3Dxjs.s.9Bth82x0PFM.L.B1.O%2Fam%3DAJA6BAgBAAAgAACAEAAqAAgAAAAAAAAAAAAAAAAAAAAAAAAAACABAAAAAgAAAAAAABAAACAQBQGImQAAAIJTAAiwAwAAAAD4ABJxKgABAEACASBASAAAgAAAAYAAsAECAAgsAIEBIAgAACAAgAMAAASAQARgv_85MACAAQAAgAAAISBEAAEYAkDjAiAhKH8_QOIHAAWEAEAAAAgAAKAEPATDAAQVAAM8QAgAAAAIAAAAAAAAEAggBAAAA1D6QwQQAKAHgADwAQBIgggAMAQAaIBCABL4AQAEAAAAgCMAAgGAAGEKAMfAAAQAAAAAAADgHgAeDwiHFBYAAAAAAAAAAAAAAAAQgATBHEh_QQACAAAAAAAAAAAAAAAAAABIETRxuQFAAQ%2Fd%3D1%2Fed%3D1%2Fdg%3D0%2Fbr%3D1%2Fujg%3D1%2Frs%3DACT90oFyvZ7kgaKtsTqOSldpVVmZhH1NwA']],
#       dtype=object)

# %%
initial_url, next_page_url
# Out:
# ('https://www.google.com/async/reviewDialog?vet=10ahUKEwjp-ue5vfmKAxWQSGcHHf1KA3cQlIwOCMUF..i&ei=PZWIZ6noH5CRnesP_ZWNuAc&opi=89978449&rlz=1C1FKPE_en-GBAU1093AU1093&sca_esv=bcbd4b002db38cd9&yv=3&cs=0&async=feature_id:0x6ad65c0c80ecdafd%3A0x4a9bb89e7998dc72,review_source:All%20reviews,sort_by:qualityScore,is_owner:false,filter_text:,associated_topic:,next_page_token:,async_id_prefix:,_pms:s,_fmt:pc,_basejs:%2Fxjs%2F_%2Fjs%2Fk%3Dxjs.s.en_GB.imokO5pDFSw.2018.O%2Fam%3DAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAACAABQEIAAAAAABQAAgAAAAAAAAAABIAAAAAAEACASBASAAAgAAAAAAAsAAAAAgsAIEBAAAAAAAAAAIAAACAQARgv_84AAAAAAAAAAAAIABEAAAAAADgAgAgCGo3QAAAAACAAAAAAAgAAAAEAAQAAAAUAAAAQAAAAAAIAAAAAAAAAAgAAAAAAQD6QwAAAAAAAAAAAAAAAgAAAAAAaIACAAL4AQAAAAAAgAMAAACAAAEAAMfAAAQAAAAAAADgHgAeDwiHFBYAAAAAAAAAAAAAAAAQgATBHEh_QQACAAAAAAAAAAAAAAAAAABIETRxuQFAAQ%2Fdg%3D0%2Fbr%3D1%2Frs%3DACT90oEmcrTwDGRBHFigA4Hte2jSNiyLXQ,_basecss:%2Fxjs%2F_%2Fss%2Fk%3Dxjs.s.7eaQE2ygUs0.L.B1.O%2Fam%%2Fbr%3D1%2Frs%3DACT90oEvTh5q2A_EcnKoNyL6Aru3GqFmuw,_basecomb:%2Fxjs%2F_%2Fjs%2Fk%3Dxjs.s.en_GB.imokO5pDFSw.2018.O%2Fck%3Dxjs.s.7eaQE2ygUs0.L.B1.O%2Fam%3DAJA6BAgBAAAgAACAEAAqAAgAAAAAAAAAAAAAAAAAAAAAAAAAACABAAAAAgAAAAAAABAAACAQBQGImQAAAIJTAAiwAwAAAAD4ABJxKgABAEACASBASAAAgAAAAYAAsAECAAgsAIEBIAgAACAAgAMAAASAQARgv_85MACAAQAAgAAAISBEAAEYAkDjAiAhKH8_QOIHAAWEAEAAAAgAAKAEPATDAAQVAAM8QAgAAAAIAAAAAAAAEAggBAAAA1D6QwQQAKAHgADwAQBIgggAMAQAaIBCABL4AQAEAAAAgCMAAgGAAGEKAMfAAAQAAAAAAADgHgAeDwiHFBYAAAAAAAAAAAAAAAAQgATBHEh_QQACAAAAAAAAAAAAAAAAAABIETRxuQFAAQ%2Fd%3D1%2Fed%3D1%2Fdg%3D0%2Fbr%3D1%2Fujg%3D1%2Frs%3DACT90oGVE-wJGFrfOI-mdQtlS-9ka9tfqQ',
#  'https://www.google.com/async/reviewSort?vet=12ahUKEwjyzJ-7vfmKAxUuSWwGHeuKD90Qxyx6BAgBED0..i&ved=2ahUKEwjyzJ-7vfmKAxUuSWwGHeuKD90Qjit6BQgBEP8C&bl=2lWB&s=web&opi=89978449&rlz=1C1FKPE_en-GBAU1093AU1093&sca_esv=bcbd4b002db38cd9&yv=3&cs=0&async=feature_id:0x6ad65c0c80ecdafd%3A0x4a9bb89e7998dc72,review_source:All%20reviews,sort_by:qualityScore,is_owner:false,filter_text:,associated_topic:,next_page_token:CAESY0NBRVFDaHBFUTJwRlNVRlNTWEJEWjI5QlVEZGZURU5IZGtKZlgxOWZSV2hEVURkUlJGOW1lSFJaU1MxWlNURTVZMEZCUVVGQlIyZHVPVEpxWjBOaVVrRlZSVVZSV1VGRFNVRQ%3D%3D,_pms:s,_fmt:pc,_basejs:%2Fxjs%2F_%2Fjs%2Fk%3Dxjs.s.en_GB.imokO5pDFSw.2018.O%2Fam%3DAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAgAAAAAAAAAAACAABQEIAAAAAABQAAgAAAAAAAAAABIAAAAAAEACASBASAAAgAAAAAAAsAAAAAgsAIEBAAAAAAAAAAIAAACAQARgv_84AAAAAAAAAAAAIABEAAAAAADgAgAgCGo3QAAAAACAAAAAAAgAAAAEAAQAAAAUAAAAQAAAAAAIAAAAAAAAAAgAAAAAAQD6QwAAAAAAAAAAAAAAAgAAAAAAaIACAAL4AQAAAAAAgAMAAACAAAEAAMfAAAQAAAAAAADgHgAeDwiHFBYAAAAAAAAAAAAAAAAQgATBHEh_QQACAAAAAAAAAAAAAAAAAABIETRxuQFAAQ%2Fdg%3D0%2Fbr%3D1%2Frs%3DACT90oEmcrTwDGRBHFigA4Hte2jSNiyLXQ,_basecss:%2Fxjs%2F_%2Fss%2Fk%3Dxjs.s.7eaQE2ygUs0.L.B1.O%2Fam%%2Fbr%3D1%2Frs%3DACT90oEvTh5q2A_EcnKoNyL6Aru3GqFmuw,_basecomb:%2Fxjs%2F_%2Fjs%2Fk%3Dxjs.s.en_GB.imokO5pDFSw.2018.O%2Fck%3Dxjs.s.7eaQE2ygUs0.L.B1.O%2Fam%3DAJA6BAgBAAAgAACAEAAqAAgAAAAAAAAAAAAAAAAAAAAAAAAAACABAAAAAgAAAAAAABAAACAQBQGImQAAAIJTAAiwAwAAAAD4ABJxKgABAEACASBASAAAgAAAAYAAsAECAAgsAIEBIAgAACAAgAMAAASAQARgv_85MACAAQAAgAAAISBEAAEYAkDjAiAhKH8_QOIHAAWEAEAAAAgAAKAEPATDAAQVAAM8QAgAAAAIAAAAAAAAEAggBAAAA1D6QwQQAKAHgADwAQBIgggAMAQAaIBCABL4AQAEAAAAgCMAAgGAAGEKAMfAAAQAAAAAAADgHgAeDwiHFBYAAAAAAAAAAAAAAAAQgATBHEh_QQACAAAAAAAAAAAAAAAAAABIETRxuQFAAQ%2Fd%3D1%2Fed%3D1%2Fdg%3D0%2Fbr%3D1%2Fujg%3D1%2Frs%3DACT90oGVE-wJGFrfOI-mdQtlS-9ka9tfqQ')

# %%
headers = {"User-Agent": "Mozilla/5.0",
           "Accept-Language": "en-US,en;q=0.9",  # Explicitly request English
           "Content-Language": "en-US"}

params = {
    "gl": "US",  # Geolocation: United States
    "hl": "en"   # Language: English
}
respond = requests.get(initial_url, headers=headers, params = params)
respond.raise_for_status() # raise an exception for 4xx and 5xx errors
initial_html = respond.content
output = crawl_reviews_async(initial_html, next_page_url)

output['StoreNo'] = 3399
output['ReviewID'] = [str(uuid.uuid4()) for _ in range(len(output))]
output['Timestamp'] = pd.to_datetime(datetime.now())
new_order = ['ReviewID','StoreNo','StoreName','UserUrl','UserName','LocalGuideBadges','ReviewTextSnippet','ReviewTextFull','Rating','TimeReview','Timestamp']
output = output[new_order]
output
# Out:
#                                  ReviewID  StoreNo           StoreName  \
# 0    9f1ac61b-0399-4da3-8454-a616927be66e     3399  Woolworths Niddrie
# 1    4ec9f2fe-50bd-460a-8f1a-b6caa76c461a     3399  Woolworths Niddrie
# 2    a1268d88-c694-4174-8de0-c617bf9c0c31     3399  Woolworths Niddrie
# 3    e22c8641-44a2-44bf-90e8-d23fb67f8d5b     3399  Woolworths Niddrie
# 4    dee5ddc1-47e7-4f12-b9c7-fd33d6c0b2ac     3399  Woolworths Niddrie
# ..                                    ...      ...                 ...
# 355  1a022387-5c00-4695-9a11-0698dc63155d     3399                 NaN
# 356  cf476b34-a0de-4df0-ba2a-e03364b2c760     3399                 NaN
# 357  20b8005a-7011-44cf-ba8d-d5a624fbbb06     3399                 NaN
# 358  9e0f3d4e-64f1-4e14-8624-f2d75038abce     3399                 NaN
# 359  c87a143e-2911-4986-99f6-a747acb8b185     3399                 NaN
#
#                                                UserUrl          UserName  \
# 0    /url?q=https://www.google.com/maps/contrib/115...             Julie
# 1    /url?q=https://www.google.com/maps/contrib/106...            Mark B
# 2    /url?q=https://www.google.com/maps/contrib/108...          Mc Melon
# 3    /url?q=https://www.google.com/maps/contrib/100...      Jordan James
# 4    /url?q=https://www.google.com/maps/contrib/105...      Kerry Jordan
# ..                                                 ...               ...
# 355  /url?q=https://www.google.com/maps/contrib/117...  Ruchika Bhandari
# 356  /url?q=https://www.google.com/maps/contrib/117...      Jack Showler
# 357  /url?q=https://www.google.com/maps/contrib/103...          Tony Siu
# 358  /url?q=https://www.google.com/maps/contrib/117...     Lidija Krčmar
# 359  /url?q=https://www.google.com/maps/contrib/117...     Kristy Fisiak
#
#     LocalGuideBadges                                  ReviewTextSnippet  \
# 0                     Woolworths Niddrie has gone downhill big time,...
# 1                     I am thrilled to share my experience with Char...
# 2
# 3
# 4        Local Guide  Drove especially to Niddrie because online sta...
# ..               ...                                                ...
# 355      Local Guide
# 356
# 357
# 358      Local Guide
# 359
#
#                                         ReviewTextFull Rating    TimeReview  \
# 0    Woolworths Niddrie has gone downhill big time,...    1.0   a month ago
# 1    I am thrilled to share my experience with Char...    5.0  2 months ago
# 2    I’m writing this to commend Jacob the Nightfil...    5.0  5 months ago
# 3    ran into a strapping man named ethan the other...    5.0   a month ago
# 4    Drove especially to Niddrie because online sta...    1.0  3 months ago
# ..                                                 ...    ...           ...
# 355                                                       5.0   6 years ago
# 356                                                       5.0   6 years ago
# 357                                                       3.0   6 years ago
# 358                                                       3.0   7 years ago
# 359                                                       5.0   7 years ago
#
#                      Timestamp
# 0   2025-01-20 23:36:03.589461
# 1   2025-01-20 23:36:03.589461
# 2   2025-01-20 23:36:03.589461
# 3   2025-01-20 23:36:03.589461
# 4   2025-01-20 23:36:03.589461
# ..                         ...
# 355 2025-01-20 23:36:03.589461
# 356 2025-01-20 23:36:03.589461
# 357 2025-01-20 23:36:03.589461
# 358 2025-01-20 23:36:03.589461
# 359 2025-01-20 23:36:03.589461
#
# [360 rows x 11 columns]

# %%
#save_output
with open('output.json', 'w') as f:
  json.dump(output, f, indent=4)
